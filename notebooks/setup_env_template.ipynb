# %%
# Copy this template and replace the placeholder locally.
env_content = "MOONSHOT_API_KEY=your-api-key-here\n"

with open(".env", "w", encoding="utf-8") as f:
    f.write(env_content)

print(".env template written. Replace the placeholder before running agent analysis.")
